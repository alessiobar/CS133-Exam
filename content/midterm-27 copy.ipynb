# %% [markdown]
# # CS 133 Foundations of Data Science - Midterm Exam
# *(20 points + 1.5 extra-credit points)*
#
# ***PLEASE READ CAREFULLY BEFORE YOU BEGIN:***
#
# - This exam has **10 problems**, including one extra-credit problem. It is worth 20 points (**20% of your final grade**), plus 1.5 extra-credit points. Some later questions depend on earlier ones, so if you cannot complete a question, still attempt any later questions that rely on it. We will award partial credit even if an earlier error causes your answer not to run correctly.
# - *You may begin as soon as you open this notebook.* You must submit by **11:45 AM**. Late submissions will *NOT* be accepted.
# - You may use one US letter-size cheat sheet, double-sided. **No AI, external searching, or collaboration** is allowed.
# - Don’t forget `help()` and `?` for documentation (e.g., `help(abs)`, `abs?`).
# - *Raise your hand if you have any questions.* In particular, we are happy to help with any platform-related issues. The **▶ button** at the top runs the current cell. The **+ button** at the top inserts a new cell below. By default, it creates a code cell. To convert it to a text cell, click "Code" in the dropdown at the top and change it to "Markdown". **Save the notebook regularly to avoid losing your work** ("File"->"Save Notebook").
# - When you are ready to submit, be sure to: **(1)** Download the notebook as an `.ipynb` file ("File"->"Download"). **(2)** Submit it to Canvas ("Assignments"->"Midterm").

# %% [markdown]
# ## Programming in Python & Data Types

# %% [markdown]
# ### (2 points) Problem 1
#
# Write a Python expression in the next cell that evaluates to
#
# $9 \times \left(100 \frac{1}{3}\right) - 20 \frac{1}{2} + 2^{0.5 \times 20} + \frac{83}{2}$
#
# Assign the resulting value to the variable `result`.

# %%
# Write your solution here.
result

# %%
# Run this cell to print the integer version of your `result`. 
# Hint: Your output should be 1948.
int(result)

# %% [markdown]
# ### (1 point) Problem 2
#
# Calculate $\log_{12} 466$. Assign the resulting value to the variable `result`.
#
# *Hint: the `log` function is not available by default. It is built into Python and stored in the `math` module.*

# %%
# Write your solution here.
import math
result

# %%
# Run this cell to print your `result`.
result

# %% [markdown]
# ## Sequences (NumPy)

# %% [markdown]
# ### (3 points) Problem 3

# %% [markdown]
# Use NumPy to create two arrays. One is `[1010, 1020, 1030, 1040]` named `arr1`. The other is `[103, 100, 97, ..., 3]` named `arr2`. Then calculate the average of each array and compare them.

# %%
# Replace `?` with your solution.
# Step 1: Create and print `arr1`.
import numpy as np
arr1 = ?
arr1

# %%
# Step 2: Create and print `arr2`.
arr2 = ?
arr2

# %%
# Step 3: Calculate the average of `arr1` and `arr2`.
# Hint: NumPy has a `mean` function to calculate the average of a numerical array.
print("The average of `arr1` is:", np.mean(arr1))
print("The average of `arr2` is:", np.mean(arr2))

# %%
# Step 4: Compare the two average scores.
# You should have already found that `arr1` is slightly larger than `arr2`.
# No need to write anything in this cell.

# %% [markdown]
# ### (2 points) Problem 4

# %% [markdown]
# Extract the first 30 elements of `arr2` and store them in `arr2_first_30`. Next, divide each element in `arr2_first_30` by 3 and store the result in `arr2_first_30_divide_by_3`. Do not use iteration such as a for loop.

# %%
# Replace `?` with your solution.
# Step 1: Extract the first 30 elements of `arr2`.
arr2_first_30 = ?
arr2_first_30

# %%
# Step 2: Divide each element in `arr2_first_30` by 3.
arr2_first_30_divide_by_3 = ?
arr2_first_30_divide_by_3

# %% [markdown]
# ## Tables (Pandas)

# %% [markdown]
# ### (3 points) Problem 5

# %% [markdown]
# **(2 points) Problem 5.1:** Use pandas to create the following table named `table`.
#
# | City      | Country   | Temperature |
# |-----------|-----------|-------------|
# | Seoul     | Korea     | 18.5        |
# | Rome      | Italy     | 22.3        |
# | Chicago   | USA       | 15.8        |

# %%
# Write your solution here.

# %%
# Run this cell to print your `table`, which helps you verify your solution.
table

# %% [markdown]
# **(1 point) Problem 5.2:** Use pandas to load the `table.csv` file and store it in `table2`.

# %%
# Run this cell to save your `table` as a CSV file named "table.csv".
table.to_csv("table.csv", index=False)

# %%
# Write your solution here.
table2

# %%
# Run this cell to print your `table2`.
# Hint: `table2` should look exactly the same as `table`.
table2

# %% [markdown]
# ### (1 point) Problem 6

# %% [markdown]
# Sort the rows of `table` based on the values in `"Temperature"` in descending order. Store the result in `table_sort`.

# %%
# Write your solution here.
# Hint: You can use pandas's `sort_values` method.
table_sort = ?

# %%
# Run this cell to print your `table_sort`, which helps you verify your solution.
table_sort

# %% [markdown]
# ### (3 points) Problem 7

# %% [markdown]
# **(1 point) Problem 7.1:** Use the `loc` *or* `iloc` method to select the second row of `table_sort`. Store the result in `table_sort_second_row`.

# %%
# Write your solution here.
table_sort_second_row = ?

# %%
# Run this cell to print your `table_sort_second_row`, which helps you verify your solution.
table_sort_second_row

# %% [markdown]
# **(2 points) Problem 7.2:** Select the row(s) of `table_sort` where `"Temperature"` is between 15.0 and 20.0. Store the result in `table_sort_select_by_temperature`.

# %%
# Write your solution here.
table_sort_select_by_temperature = ?

# %%
# Run this cell to print your `table_sort_select_by_temperature`.
# Hint: `table_sort_second_row` should refer to the same row in `sort_table` as `table_sort_select_by_temperature`.
table_sort_select_by_temperature

# %% [markdown]
# ### (2 points) Problem 8

# %% [markdown]
# For each price in `table`, round it to the nearest integer. Store the result as a new column in `table` called `"Temperature (Round)"`.

# %%
# Write your solution here.
# Hint: You can use Python’s `round` function.

# %%
# Run this cell to print your `table`, which helps you verify your solution.
table

# %% [markdown]
# ## Visualization (Matplotlib)

# %% [markdown]
# ### (3 points) Problem 9

# %% [markdown]
# Create a bar plot for `table`, where the x-axis shows each city and the y-axis shows the corresponding temperature.

# %%
# Write your solution here.

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# ### (1.5 points) Problem 10

# %% [markdown]
# **(0.5 point) Problem 10.1:** Write the first *or* last name of this course's TA.

# %% [markdown]
# **Answer:** *Write your answer here.*

# %% [markdown]
# **(0.5 point) Problem 10.2:** A bag contains three marbles: two green and one yellow. Suppose you draw two marbles at random without replacement. What is the probability that one of the two marbles is green and the other yellow (order not specified)?

# %% [markdown]
# **Answer:** *Write your answer here.*

# %% [markdown]
# **(0.5 point) Problem 10.3:** In this exam, there are 9 problems (excluding the extra credit). Assuming that the probability of answering each problem correctly is 85%, what is the probability that you would *not* receive a 0?

# %% [markdown]
# **Answer:** *Write your answer here.*
